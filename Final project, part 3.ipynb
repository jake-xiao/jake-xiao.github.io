# %% [markdown]
# # Employment facts for African American(2015-2019)

# %% [markdown]
# Jake Xiao

# %% [markdown]
# ### Introduction :

# %% [markdown]
# In the United States, African Americans constitute the second largest ethnic group, after white Americans, and the third-largest ethnic group after Hispanic and Latino Americans. For this visualization article, I want to find African Americans’ employment plans in Illinois, especially recruiting status. To meet this goal, I will use the dataset from Data.Illinois.GOV, which is open source and free.

# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from IPython.display import display, clear_output
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Information

# %% [markdown]
# 1. The dataset’s name is African American 2015 - 2018
# 2. Dataset URL: https://data.illinois.gov/datastore/dump/8d9eabcb-08c7-40ae-8252-877fb0e5788d
#     1. Creative Commons Attribution is this dataset’s License, which means that it is totally free and open source. So, you are welcome to download it.
# 3. This file is CSV file, and it is about 813 KB. Lastly, this file has 313 rows and 190 columns.

# %%
old = pd.read_csv("https://data.illinois.gov/datastore/dump/8d9eabcb-08c7-40ae-8252-877fb0e5788d",na_values = {'14b_numHired_AA': 0,
                 '3_headcount':0,
                '14_numHired':0})
old
# Out:
#      _id  RespondentID  CollectorID            StartDate              EndDate  \
# 0      1   10404006526    221656615  2018-12-07 08:36:30  2018-12-17 13:58:32
# 1      2   10404308761    221656615  2018-12-07 10:27:53  2018-12-21 14:36:13
# 2      3   10404960897    221656615  2018-12-07 14:57:43  2018-12-21 09:53:03
# 3      4   10407027125    221656615  2018-12-09 09:27:43  2018-12-20 09:20:18
# 4      5   10408846706    221656615  2018-12-10 09:43:12  2018-12-13 12:51:46
# ..   ...           ...          ...                  ...                  ...
# 308  309    6606182408    162426957  2017-12-29 16:42:34  2017-12-29 17:00:35
# 309  310    6607947177    162426957  2018-01-01 15:06:28  2018-01-04 21:59:23
# 310  311    6612059785    162426957  2018-01-04 09:45:12  2018-01-04 09:54:49
# 311  312    6614050058    162426957  2018-01-05 12:55:26  2018-01-05 14:02:09
# 312  313    6614197913    162426957  2018-01-05 14:36:39  2018-01-05 15:18:32
#
#      Year                                Agency            Agency_Director  \
# 0    2019     Commerce and Economic Opportunity              Leslie Munger
# 1    2019                         Public Health  Nirav D. Shah, M.D., J.D.
# 2    2019       Environmental Protection Agency               Alec Messina
# 3    2019                      Labor Department               Joseph Beyer
# 4    2019          Illinois Commerce Commission               Cholly Smith
# ..    ...                                   ...                        ...
# 308  2018             Capital Development Board                 Gus Behnke
# 309  2018    Developmental Disabilities Council  Kimberly Mercer-Schleider
# 310  2018                        Transportation        Randall Blankenhorn
# 311  2018       Workers Compensation Commission            Joann Fratianni
# 312  2018  Guardianship and Advocacy Commission   Dr. Mary L. Milano, Esq.
#
#             Agency_Rep                                   Agency_Rep_Title  \
# 0      Miguel Calderon  Deputy Director Equal Opportunity Monitoriting...
# 1      Robin A. Tucker                                     EEO/AA Officer
# 2         Jill Johnson                                     EEO/AA Officer
# 3    Ann Glaze Pufundt                                        HR Director
# 4      Leigh Ann Myers                            Human Resources Manager
# ..                 ...                                                ...
# 308      Debbi Denzler                            Personnel Administrator
# 309  Janinna Hendricks                       Fiscal & Operations Director
# 310  Clarissa Williams               Diversity & Recruiting Section Chief
# 311    Brendan ORourke                        Director of Human Resources
# 312            Gia Orr          EEO/AA/504 Officer/ Chief Results Officer
#
#      ...        56a_1PositionName 56b_1PositionType 56c_1Eligible  \
# 0    ...                                                        0
# 1    ...  Office Associate, Opt 2          New Hire           203
# 2    ...     Laboratory Assistant          New Hire             7
# 3    ...  Public Safety Inspector          New Hire             6
# 4    ...                                                        0
# ..   ...                      ...               ...           ...
# 308  ...                                                        0
# 309  ...                                                        0
# 310  ...                                                        0
# 311  ...                                                        0
# 312  ...                                                        0
#
#      56d_1EligibleAA  56e_1Interview  56f_1InterviewAA  56g_1DidInterview  \
# 0                  0               0                 0                  0
# 1                  8              12                 0                  2
# 2                  0               7                 0                  4
# 3                  0               6                 0                  3
# 4                  0               0                 0                  0
# ..               ...             ...               ...                ...
# 308                0               0                 0                  0
# 309                0               0                 0                  0
# 310                0               0                 0                  0
# 311                0               0                 0                  0
# 312                0               0                 0                  0
#
#      56h_1DidInterviewAA  56i_1Offered  56j_1OfferedAA
# 0                      0             0               0
# 1                      0             2               0
# 2                      0             1               0
# 3                      0             1               0
# 4                      0             0               0
# ..                   ...           ...             ...
# 308                    0             0               0
# 309                    0             0               0
# 310                    0             0               0
# 311                    0             0               0
# 312                    0             0               0
#
# [313 rows x 190 columns]

# %% [markdown]
# ### Data Selection

# %% [markdown]
# I first created a pivot table for data visualization to find the African American's hiring facts. For this table, the index is Agency. These Agencies are state entities completing the survey in Illinois. And the column is the Year between 2015 to 2019. Lastly, For the value, I choose the 14_numHired column. According to the websites, this column describes how many employees were hired during the last fiscal year according to the websites? Include new "off the street" hires from the Open Competitive list of eligible and inter and intra agency transfers of current state employees, promotions, voluntary reductions, lateral moves, etc. This can be really helpful.

# %%
df=old.pivot(index="Agency",values="14_numHired",columns='Year')
df
# Out:
# Year                                              2014    2015    2016  \
# Agency
# Abraham Lincoln Presidential Library and Museum    NaN     NaN     NaN
# Aging                                             31.0    26.0    40.0
# Agriculture                                       26.0    32.0    25.0
# Arts Council                                       1.0     1.0     NaN
# Capital Development Board                         21.0    18.0    24.0
# Central Management Services                      104.0   174.0    42.0
# Children and Family Services                     132.0   210.0   201.0
# Civil Service Commission                           NaN     NaN     NaN
# Commerce and Economic Opportunity                 28.0    34.0    42.0
# Corrections                                      612.0  1724.0  2391.0
# Criminal Justice Information Authority             NaN     5.0     3.0
# Deaf and Hard of Hearing Commission                1.0     NaN     NaN
# Developmental Disabilities Council                 1.0     NaN     NaN
# Emergency Management Agency                        9.0    19.0    19.0
# Employment Security                               65.0    44.0   138.0
# Environmental Protection Agency                   16.0    52.0    17.0
# Executive Ethics Commission                       10.0    10.0     7.0
# Financial and Professional Regulation             21.0    76.0    88.0
# Gaming Board                                      25.0    19.0    17.0
# Guardianship and Advocacy Commission               4.0     3.0     4.0
# Healthcare and Family Services                   188.0   256.0   248.0
# Historic Preservation                              6.0    23.0     8.0
# Human Rights Commission                            1.0     1.0     1.0
# Human Rights Department                           11.0    11.0     6.0
# Human Services                                   840.0  2289.0  2337.0
# Illinois Board of Higher Education                 NaN     NaN    10.0
# Illinois Commerce Commission                      10.0     8.0    20.0
# Illinois Health Information Exchange Authority     NaN    11.0     5.0
# Illinois Housing Development Authority             NaN     NaN     NaN
# Illinois State Board of Education                  NaN    70.0     NaN
# Innovation and Technology                          NaN     NaN     NaN
# Inspector General                                 18.0     NaN     NaN
# Insurance                                         29.0    52.0    43.0
# Investment Board                                   1.0     1.0     2.0
# Juvenile Justice                                  40.0   125.0   109.0
# Labor Department                                  12.0    28.0    25.0
# Labor Relations Board                              3.0     2.0     1.0
# Labor Relations Board - Educational                NaN     2.0     1.0
# Law Enforcement Training and Standards Board       NaN     3.0     3.0
# Sentencing Policy Advisory Council                  2.0     NaN     NaN
# State Fire Marshal                                  8.0    23.0    26.0
# State Police                                       40.0    52.0   185.0
# State Police Merit Board                            NaN     NaN     NaN
# State Retirement Systems                           14.0    10.0     NaN
# Tax Tribunal                                        NaN     NaN     NaN
# Transportation                                    666.0   993.0  1041.0
# Veterans Affairs                                  150.0   157.0   186.0
# Workers Compensation Commission                    14.0    15.0     6.0

# %% [markdown]
# ### First Interactive Visualization

# %% [markdown]
# I used the ipywidgets dropdown method to show the pivot table for this interactive visualization. Moreover, I created a sector for the user to click on. This sector included all the agency’s names in it. Users can click one of the agencies, then these codes can provide the number of hiring employees every year.

# %%
filtered_df = None

dropdown = widgets.SelectMultiple(
                        options=df.index,
                        description='Sector',
                        disabled=False,
                        layout={'height':'200px', 'width':'60%'})

def filter_dataframe(widget):
    global filtered_df
    selection = list(widget['new'])

    with out:
        clear_output()
        display(df.loc[selection])
        filtered_df = df.loc[selection]

out = widgets.Output()
dropdown.observe(filter_dataframe, names='value')
display(dropdown)
display(out)
# Out:
# SelectMultiple(description='Sector', layout=Layout(height='200px', width='60%'), options=('Abraham Lincoln Pre…
# Output()

# %% [markdown]
# ### Second Interactive Visualization

# %%
df2=old.pivot(index="Agency",values="14b_numHired_AA",columns='Year')
filtered_df2 = None
dropdown2 = widgets.SelectMultiple(
                        options=df2.index,
                        description='Sector',
                        disabled=False,
                        layout={'height':'200px', 'width':'60%'})

def filter_dataframe2(widget):
    global filtered_df2
    selection2 = list(widget['new'])

    with new_out:
        clear_output()
        display(df2.loc[selection2])
        filtered_df2 = df2.loc[selection2]

new_out = widgets.Output()
dropdown2.observe(filter_dataframe2, names='value')
display(dropdown2)
display(new_out)
# Out:
# SelectMultiple(description='Sector', layout=Layout(height='200px', width='60%'), options=('Abraham Lincoln Pre…
# Output()

# %% [markdown]
# For the second interactive visualization, it is really similar to the first one. Frist is to create another pivot table. The index and the columns are the same as the first pivot table. But for the second pivot table’s values, I choose the 14b_numHired_AA column because this can tell me how many of those hiring people were African American, which can make a comparison with the first interactive visualization.

# %% [markdown]
# ### Contextual Visualizations:

# %% [markdown]
# For the contextual Visualizations, I chose three graphs from the original website. The Data.Illinois.GOV website allows users to graph charts. Therefore, I chose the Agency as Axis one, 14_numHired, and 14b_numHired_AA as the Axis 2 to show how many African Americans are included from the total more easily. And for the last visualizations. it shows the people’s increased and decreased.

# %%
import PIL.Image as image
one=image.open("/Users/Alienware/Desktop/one.png")
two=image.open("/Users/Alienware/Desktop/two.png")
three=image.open("/Users/Alienware/Desktop/three.png")
display(one,two,three)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1368x752 at 0x15B904D5580>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1354x752 at 0x15B9333F8B0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1371x759 at 0x15B933D1B20>

# %%
plt.rcParams['figure.figsize']=(6,4)
plt.rcParams['figure.dpi']=150

# %%
sample=old[[ 'Agency','Year', '14_numHired', '14b_numHired_AA']]
new_sample=old.pivot(index="Year",values="14b_numHired_AA",columns='Agency').plot(kind='line')

plt.legend(['Line1', 'Sine','who'])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ### Citation:

# %% [markdown]
# African American, Asian American and Hispanic Employment Plan Surveys - African american 2015 - 2018. data.illinois.gov. (2019, February 1). Retrieved December 8, 2021, from https://data.illinois.gov/dataset/employment-plan-surveys/resource/8d9eabcb-08c7-40ae-8252-877fb0e5788d.

# %% [markdown]
# Dataset Url:https://data.illinois.gov/datastore/dump/8d9eabcb-08c7-40ae-8252-877fb0e5788d
